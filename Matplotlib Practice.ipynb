# %%
import matplotlib
matplotlib.__version__
# Out:
# '3.3.4'

# %%
# %matplotlib inline

# %%
# Import dependencies.
import matplotlib.pyplot as plt

# %%
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
# Create the plot
plt.plot(x_axis, y_axis)

# %%
# Create the plot with ax.plt()
fig, ax = plt.subplots()
ax.plot(x_axis, y_axis)

# %%
# Create the plot with ax.plt()
fig = plt.figure()
ax = fig.add_subplot()

# %%
# Create the plot with ax.plt()
ax = plt.axes()
ax.plot(x_axis, y_axis)

# %%
# Create the plot.
plt.plot(x_axis, y_axis)
plt.show()

# %%
# Create the plot and add a label for the legend.
plt.plot(x_axis, y_axis, label='Boston')
# Create labels for the x and y axes.
plt.xlabel("Date")
plt.ylabel("Fare($)")
# Set the y limit between 0 and 45.
plt.ylim(0, 45)
# Create a title.
plt.title("PyBer Fare by Month")
# Add the legend.
plt.legend()

# %%
# Create the plot.
plt.plot(x_axis, y_axis, marker="*", color="blue", linewidth=2, label='Boston')
# Create labels for the x and y axes.
plt.xlabel("Date")
plt.ylabel("Fare($)")
# Set the y limit between 0 and 45.
plt.ylim(0, 45)
# Create a title.
plt.title("PyBer Fare by Month")
# Add a grid.
plt.grid()
# Add the legend.
plt.legend()

# %%
# Create the plot.
plt.plot(x_axis, y_axis, marker="^", color="green", linewidth=2, label='Boston')
# Create labels for the x and y axes.
plt.xlabel("Date")
plt.ylabel("Fare($)")
# Set the y limit between 0 and 45.
plt.ylim(0, 45)
# Create a title.
plt.title("PyBer Fare by Month")
# Add a grid.
plt.grid()
# Add the legend.
plt.legend()

# Change the line color to green.
# Change the marker to a diamond.
# Change the line width to 2 points.
# Add a legend for the city of Boston.
# Add a title and axes labels.
# Add a y-axis limit.
# Add grid lines.

# %%
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
# Create the plot
plt.bar(x_axis, y_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
# Create the plot.
plt.bar(x_axis, y_axis, color="green", label='Boston')
# Create labels for the x and y axes.
plt.xlabel("Date")
plt.ylabel("Fare($)")
# Create a title.
plt.title("PyBer Fare by Month")
# Add the legend.
plt.legend()

# %%
# Create the plot
plt.barh(x_axis, y_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
# Create the plot
plt.barh(y_axis, x_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
# Create the plot.
plt.barh(x_axis, y_axis)
# Put months on y axis in the right order
plt.gca().invert_yaxis()

# %%
# Create the plot.
plt.barh(x_axis, y_axis, color="magenta", label='Boston')
# Create labels for the x and y axes.
plt.xlabel("Date")
plt.ylabel("Fare($)")
# Create a title.
plt.title("PyBer Fare by Month")
# Add the legend.
plt.legend()

# %%
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
# Create the plot with ax.plt()
fig, ax = plt.subplots()
ax.bar(x_axis, y_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
# Create the plot with ax.plt()
fig, ax = plt.subplots()
ax.barh(x_axis, y_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
# Create the plot with ax.plt() data on opposite axes from above
fig, ax = plt.subplots()
ax.barh(y_axis, x_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
# Create the plot.
plt.barh(x_axis, y_axis, color="cyan", label='Chicago')
# Put months on y axis in the right order
plt.gca().invert_yaxis()
# Create labels for the x and y axes.
plt.xlabel("Date")
plt.ylabel("Fare($)")
# Create a title.
plt.title("PyBer Fare by Month")
# Add the legend.
plt.legend()

# %%
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
# Adding the 'o' makes it a scatter plot instead of a line chart
plt.plot(x_axis, y_axis, 'o')

# %%
# Create a scatter plot with different formula 
plt.scatter(x_axis, y_axis)

# %%
# Create the plot.
plt.scatter(y_axis, x_axis, color="red", label='Chicago')
# Put months on y axis in the right order
plt.gca().invert_yaxis()
# Create labels for the x and y axes.
plt.ylabel("Date")
plt.xlabel("Fare($)")
# Create a title.
plt.title("PyBer Fare by Month")
# Set the x limit between 0 and 45.
plt.xlim(0, 50)
# Add the legend.
plt.legend()

# %%
# Change size of the markers based on y axis numbers
plt.scatter(x_axis, y_axis, s=y_axis)

# %%
# Adjust size of markers -- still relative to y-axis values
y_axis_larger = []
for data in y_axis:
  y_axis_larger.append(data*3)

# %%
# Use new y-axis perameter 
plt.scatter(x_axis, y_axis, s=y_axis_larger)

# %%
plt.scatter(x_axis, y_axis, s = [i * 3 for i in y_axis])

# %%
# Create a scatterplot using object oriented interface method
fig, ax = plt.subplots()
ax.scatter(x_axis, y_axis)

# %%
# Create a bubble chart using the OOI 
fig, ax = plt.subplots()
ax.scatter(x_axis, y_axis, s=y_axis)

# %%
plt.scatter(y_axis, x_axis, s = [i * 5 for i in y_axis], )
# Change the color of the markers to sky blue.

# Change the size of the markers to 5 times each data point.
# Make the color 20% transparent.
# Add a black edge color to the circles.
# Make the linewidth of the circles 2 points.

# Add a legend for the city of Boston.
plt.legend("Boston")
# Add a title.
plt.title("PyBer Fare by Month")
# Switch the axis so that the Fare($) data is on the x-axis.

# Add a limit for the x-axis data.
plt.xlim(0, 50)
# Invert the y-axis so that January is at the top.
plt.gca().invert_yaxis()


# Create labels for the x and y axes.
plt.ylabel("Date")
plt.xlabel("Fare($)")
# Out:
# Text(0.5, 0, 'Fare($)')

# %%
# Create a pie chart using pyplot 
plt.pie(y_axis, labels=x_axis)
plt.show()

# %%
# Increase the size of the pie chart 
plt.subplots(figsize=(8, 8))
# Explode one value, July out of the chart 
explode_values = (0, 0, 0, 0, 0, 0, 0.2, 0, 0, 0, 0, 0)
# Label the slices and make it appear as percentages 
plt.pie(y_axis, explode=explode_values, labels=x_axis, autopct='%.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7fc0978f5760>,
#   <matplotlib.patches.Wedge at 0x7fc0978f5e50>,
#   <matplotlib.patches.Wedge at 0x7fc097902520>,
#   <matplotlib.patches.Wedge at 0x7fc097902bb0>,
#   <matplotlib.patches.Wedge at 0x7fc097910280>,
#   <matplotlib.patches.Wedge at 0x7fc097910910>,
#   <matplotlib.patches.Wedge at 0x7fc097910fa0>,
#   <matplotlib.patches.Wedge at 0x7fc09791d670>,
#   <matplotlib.patches.Wedge at 0x7fc09791dd00>,
#   <matplotlib.patches.Wedge at 0x7fc09792c3d0>,
#   <matplotlib.patches.Wedge at 0x7fc09788e430>,
#   <matplotlib.patches.Wedge at 0x7fc09793b100>],
#  [Text(1.0940372721655667, 0.11437852557419124, 'Jan'),
#   Text(0.9905193092273052, 0.4784051609753622, 'Feb'),
#   Text(0.4998632656180861, 0.9798656620606842, 'Mar'),
#   Text(-0.32930826971286276, 1.0495504101750999, 'April'),
#   Text(-0.9306200792045569, 0.5864693241605263, 'May'),
#   Text(-1.0983369533258995, -0.06046434452452757, 'June'),
#   Text(-0.913463027456946, -0.9249785389235748, 'July'),
#   Text(-0.23338752507546193, -1.0749559354406817, 'Aug'),
#   Text(0.021097559209412746, -1.099797660024518, 'Sept'),
#   Text(0.460981299980763, -0.9987473359504124, 'Oct'),
#   Text(0.8868706338501641, -0.6507384104340302, 'Nov'),
#   Text(1.0760953148482877, -0.22807646384834376, 'Dec')],
#  [Text(0.5967476029993999, 0.06238828667683158, '3.3%'),
#   Text(0.5402832595785301, 0.2609482696229248, '7.7%'),
#   Text(0.27265269033713785, 0.5344721793058277, '13.0%'),
#   Text(-0.17962269257065241, 0.5724820419136908, '11.7%'),
#   Text(-0.5076109522933946, 0.3198923586330143, '10.7%'),
#   Text(-0.5990928836323088, -0.03298055155883321, '8.9%'),
#   Text(-0.562131093819659, -0.5692175624145076, '14.5%'),
#   Text(-0.1273022864047974, -0.5863396011494626, '3.5%'),
#   Text(0.011507759568770587, -0.5998896327406462, '3.9%'),
#   Text(0.2514443454440525, -0.5447712741547703, '9.2%'),
#   Text(0.4837476184637258, -0.35494822387310737, '6.9%'),
#   Text(0.5869610808263387, -0.12440534391727841, '6.6%')])

# %%
# Assign 12 colors, one for each month.
colors = ["slateblue", "magenta", "lightblue", "green", "yellowgreen", "greenyellow", "yellow", "orange", "gold", "indianred", "tomato", "mistyrose"]
explode_values = (0, 0, 0, 0, 0, 0, 0.2, 0, 0, 0, 0, 0)
plt.subplots(figsize=(8, 8))
plt.pie(y_axis,
    explode=explode_values,
    colors=colors,
    labels=x_axis)
        
plt.show()

# %%
# Create a pie chart using the object oriented interface 
fig, ax = plt.subplots()
ax.pie(y_axis,labels=x_axis)
plt.show()

# %%
colors = ["slateblue", "magenta", "lightblue", "green", "yellowgreen", "greenyellow", "yellow", "orange", "gold", "indianred", "tomato", "mistyrose"]
explode_values = (0, 0, 0.3, 0, 0, 0, 0.2, 0, 0, 0, 0, 0)
plt.subplots(figsize=(8, 8))
plt.pie(y_axis,
    explode=explode_values,
    colors=colors,
    labels=x_axis,
    autopct='%.1f%%',
    shadow= True, 
    startangle=99,
    counterclock=False)

plt.show()

# %%
# %matplotlib inline
# Import dependencies -- adding statistics to do calculations like stdev in error bar
import matplotlib.pyplot as plt
import statistics

# %%
# Data for the following charts
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
# Get the standard deviation of the values in the y-axis.
stdev = statistics.stdev(y_axis)
stdev
# Out:
# 11.208367917035753

# %%
plt.errorbar(x_axis, y_axis, yerr=stdev)
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
#Pyplot appraoch
plt.errorbar(x_axis, y_axis, yerr=stdev, capsize=3)
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
# OOI approach
fig, ax = plt.subplots()
ax.errorbar(x_axis, y_axis, yerr=stdev, capsize=3)
plt.show()

# %%
# Pyplot approach for a bar chart
plt.bar(x_axis, y_axis, yerr=stdev, capsize=3)
# Out:
# <BarContainer object of 12 artists>

# %%
# OOI approach for bar chart
fig, ax = plt.subplots()
ax.bar(x_axis, y_axis, yerr=stdev, capsize=3)
plt.show()

# %%
#Adjust the ticks or spacing on the x-axis to be $5 increments
#import NumPy a library used to create arrays or matrices 
import numpy as np
# horizontal bar chart, pass x and y data inside the ()
plt.barh(x_axis, y_axis)
# Space the ticks by 5 dollar steps 
plt.xticks(np.arange(0, 51, step=5.0))
# get the current axes and invert them 
plt.gca().invert_yaxis()

# %%
# create an array from 0 to 51 with increments of 5 
np.arange(0, 51, step=5.0)
# Out:
# array([ 0.,  5., 10., 15., 20., 25., 30., 35., 40., 45., 50.])

# %%
# same graph using object oriented 
fig, ax = plt.subplots()
ax.barh(x_axis, y_axis)
ax.set_xticks(np.arange(0, 51, step=5.0))
plt.show()

# %%
from matplotlib.ticker import MultipleLocator
# Increase the size of the plot figure.
fig, ax = plt.subplots(figsize=(8, 8))
ax.barh(x_axis, y_axis)
ax.set_xticks(np.arange(0, 51, step=5.0))

# Create minor ticks at an increment of 1.
ax.xaxis.set_minor_locator(MultipleLocator(1))
plt.show()
